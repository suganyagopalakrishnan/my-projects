# %%
import pandas as pd

# %%
bond_dataset=pd.read_csv("/Users/Suganya/Downloads/jamesbond.csv").convert_dtypes()

# %%
bond_dataset.head()
# Out:
#    Year                  Movie          Bond       Director      Composer  \
# 0  1962                 Dr. No  Sean Connery  Terence Young  Monty Norman
# 1  1963  From Russia with Love  Sean Connery  Terence Young    John Barry
# 2  1964             Goldfinger  Sean Connery   Guy Hamilton    John Barry
# 3  1965            Thunderball  Sean Connery  Terence Young    John Barry
# 4  1967    You Only Live Twice  Sean Connery  Lewis Gilbert    John Barry
#
#                                               Writer Cinematographer  \
# 0  Richard Maibaum, Johanna Harwood & Berkely Mather       Ted Moore
# 1                  Richard Maibaum & Johanna Harwood       Ted Moore
# 2                        Richard Maibaum & Paul Dehn       Ted Moore
# 3                     Richard Maibaum & John Hopkins       Ted Moore
# 4                                         Roald Dahl   Freddie Young
#
#                                    Depicted_Film_Loc  \
# ...

# %%
d={ "Release": "release_date",
   ...:     "Movie": "movie_title",
   ...:     "Bond": "bond_actor",}

# %%
d
# Out:
# {'Release': 'release_date', 'Movie': 'movie_title', 'Bond': 'bond_actor'}

# %%
bond_dataset.columns
# Out:
# Index(['Year', 'Movie', 'Bond', 'Director', 'Composer', 'Writer',
#        'Cinematographer', 'Depicted_Film_Loc', 'Shooting_Loc', 'Bond_Car_MFG',
#        'Bond_Girl_Nat', 'US_Gross', 'US_Adj', 'World_Gross', 'World_Adj',
#        'Budget', 'Budget_Adj', 'Film_Length', 'Avg_User_IMDB',
#        'Avg_User_Rtn_Tom', 'Conquests', 'Martinis', 'BJB', 'Kills_Bond',
#        'Kills_Others', 'Top_100', 'Video_Game'],
#       dtype='object')

# %%
bond_dataset[bond_dataset.select_dtypes('number').columns.to_list()]
# Out:
#     Year   US_Gross  US_Adj  World_Gross  World_Adj  Budget  Budget_Adj  \
# 0   1962   16067035  123517     59567035     457928    1000        7688
# 1   1963   24800000  188161     78900000     598624    2000       15174
# 2   1964   51100000  382699    124900000     935404    3000       22468
# 3   1965   63600000  468754    141200000    1040693    9000       66333
# 4   1967   43100000  299591    111600000     775740    9500       66035
# 5   1969   22800000  144234     82000000     518736    8000       50608
# 6   1971   43800000  251083    116000000     664969    7200       41274
# 7   1973   35400000  185105    161800000     846046    7000       36603
# 8   1974   21000000   98894     97600000     459623    7000       32965
# 9   1977   46800000  179297    185400000     710290   14000       53636
# 10  1979   70300000  224811    210300000     672514   31000       99134
# 11  1981   54800000  139964    195300000     498812   28000       71514
# ...

# %%
bond_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     Int64
#  1   Movie              24 non-null     string
#  2   Bond               24 non-null     string
#  3   Director           24 non-null     string
#  4   Composer           24 non-null     string
#  5   Writer             24 non-null     string
#  6   Cinematographer    24 non-null     string
#  7   Depicted_Film_Loc  24 non-null     string
#  8   Shooting_Loc       24 non-null     string
#  9   Bond_Car_MFG       24 non-null     string
#  10  Bond_Girl_Nat      24 non-null     string
#  11  US_Gross           24 non-null     Int64
#  12  US_Adj             24 non-null     Int64
#  13  World_Gross        24 non-null     Int64
#  14  World_Adj          24 non-null     Int64
#  15  Budget             24 non-null     Int64
# ...

# %%
bond_dataset.isna().any(axis="columns")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# dtype: bool

# %%
bond_dataset[bond_dataset.isna().any(axis="columns")]
# Out:
# Empty DataFrame
# Columns: [Year, Movie, Bond, Director, Composer, Writer, Cinematographer, Depicted_Film_Loc, Shooting_Loc, Bond_Car_MFG, Bond_Girl_Nat, US_Gross, US_Adj, World_Gross, World_Adj, Budget, Budget_Adj, Film_Length, Avg_User_IMDB, Avg_User_Rtn_Tom, Conquests, Martinis, BJB, Kills_Bond, Kills_Others, Top_100, Video_Game]
# Index: []
#
# [0 rows x 27 columns]

# %%
bond_dataset.isna()
# Out:
#      Year  Movie   Bond  Director  Composer  Writer  Cinematographer  \
# 0   False  False  False     False     False   False            False
# 1   False  False  False     False     False   False            False
# 2   False  False  False     False     False   False            False
# 3   False  False  False     False     False   False            False
# 4   False  False  False     False     False   False            False
# 5   False  False  False     False     False   False            False
# 6   False  False  False     False     False   False            False
# 7   False  False  False     False     False   False            False
# 8   False  False  False     False     False   False            False
# 9   False  False  False     False     False   False            False
# 10  False  False  False     False     False   False            False
# 11  False  False  False     False     False   False            False
# 12  False  False  False     False     False   False            False
# ...
